# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression

# %%
dataFrame = pd.read_csv("HR_comma_sep.csv")
dataFrame
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
dataFrame.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %%
dataFrame.tail()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 14994                   151                   3              0     1
# 14995                   160                   3              0     1
# 14996                   143                   3              0     1
# 14997                   280                   4              0     1
# 14998                   158                   3              0     1
#
#        promotion_last_5years Department salary
# 14994                      0    support    low
# 14995                      0    support    low
# 14996                      0    support    low
# ...

# %%
dataFrame.iloc[5600:5660]
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# 5600                0.22             0.58               2
# 5601                0.63             0.79               5
# 5602                0.68             0.53               3
# 5603                0.52             0.49               3
# 5604                0.22             0.52               6
# 5605                0.51             0.82               3
# 5606                0.66             0.92               4
# 5607                0.26             0.37               2
# 5608                0.42             0.40               3
# 5609                0.86             0.77               5
# 5610                0.52             0.68               3
# 5611                0.95             0.64               3
# 5612                0.63             0.94               2
# 5613                1.00             0.54               3
# 5614                0.54             0.58               3
# ...

# %%
dummies = pd.get_dummies(dataFrame[["salary"]])
dummies
# Out:
#        salary_high  salary_low  salary_medium
# 0                0           1              0
# 1                0           0              1
# 2                0           0              1
# 3                0           1              0
# 4                0           1              0
# ...            ...         ...            ...
# 14994            0           1              0
# 14995            0           1              0
# 14996            0           1              0
# 14997            0           1              0
# 14998            0           1              0
#
# [14999 rows x 3 columns]

# %%
y_var = dummies.drop("salary_medium", axis = "columns")
y_var
# Out:
#        salary_high  salary_low
# 0                0           1
# 1                0           0
# 2                0           0
# 3                0           1
# 4                0           1
# ...            ...         ...
# 14994            0           1
# 14995            0           1
# 14996            0           1
# 14997            0           1
# 14998            0           1
#
# [14999 rows x 2 columns]

# %%
X_var = dataFrame.drop("salary", axis = "columns")
X_var
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
# %matplotlib inline
for (columnName, columnData) in .iteritems():
    sns.relplot(data = train, x = columnName, y = 'site_eui', sizes=(10, 200), alpha = 0.5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [17], in <cell line: 4>()
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
#       2 plt.ylabel("Per Capita Income (US$)")
# ----> 4 plt.scatter(df[["year"]], df[["per capita income (US$)"]], color = "green")
#
# NameError: name 'df' is not defined
